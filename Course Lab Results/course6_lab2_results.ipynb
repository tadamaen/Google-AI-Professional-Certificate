# %% [markdown]
# ### **Step 1: Extract and format data from an image**
#
# #### **Prompt:**
# Extract the reviews from this screenshot and turn them into a table with the following columns - Review Number, Date, No. Of Stars, Review.
#
# #### **Gemini Result:**
# Here is the table extracting the reviews, dates, and star ratings from the provided screenshot:
#
# <table border="1" cellpadding="6" cellspacing="0">
#   <tr>
#     <th>Review Number</th>
#     <th>Date</th>
#     <th>No. Of Stars</th>
#     <th>Review</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Mar 23</td>
#     <td>2</td>
#     <td>Sizing is inconsistent. I ordered two pairs in the same size and they were completely different.</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Mar 1</td>
#     <td>5</td>
#     <td>The sizing chart was spot on. I appreciate that there were no surprises with the fit.</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Feb 27</td>
#     <td>4</td>
#     <td>The 'charcoal grey' is a lovely shade. The quality seems decent for the price.</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>Feb 15</td>
#     <td>5</td>
#     <td>I'm obsessed with the wide-leg style! They fit beautifully and are so flattering.</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>Feb 12</td>
#     <td>3</td>
#     <td>The color I received was not even close to the picture on the website. This is misleading.</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>Feb 1</td>
#     <td>5</td>
#     <td>I love the color of these trousers, it's exactly as pictured. The quality feels very durable, too.</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>Jan 31</td>
#     <td>4</td>
#     <td>I had an issue with a wrong item being shipped, but customer service fixed it immediately.</td>
#   </tr>
#   <tr>
#     <td>8</td>
#     <td>Jan 22</td>
#     <td>1</td>
#     <td>The fabric is so thin, it's practically see-through. I can't wear these in public.</td>
#   </tr>
#   <tr>
#     <td>9</td>
#     <td>Jan 21</td>
#     <td>2</td>
#     <td>The trousers are okay, but they wrinkle very easily which is a pain to deal with.</td>
#   </tr>
#   <tr>
#     <td>10</td>
#     <td>Jan 18</td>
#     <td>1</td>
#     <td>The seam came undone on the leg after two weeks. This is unacceptable.</td>
#   </tr>
# </table>
#
# * Click on **Export To Sheets** when prompted or given the option to do so.
# * Ask Gemini to remove the word PDF on all entries in Column B, C and D.

# %% [markdown]
# ### **Step 2: Annotate your data**
#
# #### **Prompt:**
# = AI("Analyze the customer feedback review in column D and classify it into five possible values, Highly Positive, Slightly Positive, Neutral, Slightly Negative or Very Negative", D2)
#
# #### **Gemini Result:**
# Refer to the Excel Sheet called **"Review Spreadsheet"**.
