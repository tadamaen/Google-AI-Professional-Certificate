# %% [markdown]
# ### **Step 1: Edit slide text**
#
# #### **Prompt:**
# I’d like to make slide 4 more readable. Write three sets of short headlines and descriptions, that can replace the text on this slide.
#
# #### **Gemini Result:**
# Here are three sets of short headlines and descriptions based on the content of Slide 4:
#
# **Actionable Data Insights**
#
# Turn raw data into strategic intelligence with robust measurement, custom GA4 implementation, and Looker Studio dashboards.
#
# **Secure Google Workspace Management**
#
# Comprehensive, hands-on administration covering efficient user lifecycle, custom application control, and robust security configuration.
#
# **Boost Online Visibility**
#
# Optimize your digital storefront for local search success using Google Business Profile (GBP) management and accurate GTM implementation.

# %% [markdown]
# ### **Step 2: Generate images for your key points**
#
# #### **Prompt:**
# - Generate an image to illustrate a database. Make it red and the background in light blue.
# - Generate an image to illustrate a security network. Make the network multi-coloured and the background in light grey.
# - Generate an image to illustrate a computer at a website. Make the website colourful and the background in light red.
#
# #### **Gemini Result:**
# Refer to updated **Debut Depot Intro Deck (Slide 4)**
