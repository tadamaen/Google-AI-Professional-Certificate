# %% [markdown]
# ### **Step 1: Build the slide deck**
#
# #### **Prompt:**
# Acting as an expert presentation slide designer and maker, help me create a text-only slide deck based on the uploaded document about "Debug Depot: Services & Capabilities 2025".
#
# ### **Step 2: Edit your slides**
#
# #### **Prompt:**
# Make the tone of the entire deck more enthusiastic and sales-focused, capturing the attention of the audience. Formality and tone can be more informal and directed.
#
# ### **Step 3: Customize for different audiences**
#
# #### **Prompt:**
# Change the slide deck to be for an internal onboarding deck for new hires. Use only the information provided in the slides.
#
# #### **Gemini Result:**
# Please refer to **Generated Slides** in the Github Folder.
